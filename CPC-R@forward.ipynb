# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
from datetime import datetime
rcParams['figure.figsize'] = 15, 6

import cv2

import xlrd
#import numpy as np
#import cv2
exfile = xlrd.open_workbook('data.xls')
data = exfile.sheet_by_name('ionosphere')
Array=[]
#BLUE=[255,0,0]
for row in range(351):
    leave=0
    for column in range(36):
        if data.cell(row,column).value=='?':
            leave=1
            break
    if leave==1:
        continue
    List=[]
    for column in range(35):
        List.append(data.cell(row,column).value)
    for column in range(34,36):
        List.append(data.cell(row,column).value)
    Array.append(List)

# %%
import math
#w=int(input())
#print(Array[379])
#w=int(input())
w=100
imglist=[]
cnt=0
for i in range(len(Array)):
    img=np.ones(shape=(20,20))
    r=int(Array[i][2])-1
    c=int(Array[i][1])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    img[r][c]=0
    
    r=int(Array[i][4])-1
    c=int(Array[i][3])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    img[r][c]=0.3
    r=int(Array[i][6])-1
    c=int(Array[i][5])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    img[r][c]=0.3
    r=int(Array[i][8])-1
    c=int(Array[i][7])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    img[r][c]=0.3
    r=int(Array[i][10])-1
    c=int(Array[i][9])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    img[r][c]=0.35
    r=int(Array[i][12])-1
    c=int(Array[i][11])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
 
    img[r][c]=0.4
    r=int(Array[i][14])-1
    c=int(Array[i][13])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    img[r][c]=0.45
    r=int(Array[i][16])-1
    c=int(Array[i][15])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    
    img[r][c]=0.5
    r=int(Array[i][18])-1
    c=int(Array[i][17])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    
    img[r][c]=0.55
    r=int(Array[i][20])-1
    c=int(Array[i][19])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.60
    r=int(Array[i][22])-1
    c=int(Array[i][21])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.65
    r=int(Array[i][24])-1
    c=int(Array[i][23])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.67
    r=int(Array[i][26])-1
    c=int(Array[i][25])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.69
    r=int(Array[i][28])-1
    c=int(Array[i][27])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.72
    r=int(Array[i][30])-1
    c=int(Array[i][29])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.75
    r=int(Array[i][32])-1
    c=int(Array[i][31])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
        
    img[r][c]=0.77
    r=int(Array[i][34])-1
    c=int(Array[i][33])-1
    if img[r][c]!=1:
        shift=1
        k=1
        while(1):
            if c+shift<10 and img[r][c+shift]==1:
                c+=shift
                break
            elif r+shift<10 and img[r+shift][c]==1:
                r+=shift
                break
            elif c-shift>=0 and img[r][c-shift]==1:
                c-=shift
                break
            elif r-shift>=0 and img[r-shift][c]==1:
                r-=shift
                break
            elif ((r+shift)<10) and ((c+1)<10) and (img[r+shift][c+k])==1:
                r+=shift
                c+=k
                break
            elif ((r-shift)>=0) and ((c+1)<10) and (img[r-shift][c+k])==1:
                r-=shift
                c+=k
                break
            elif ((r+shift)<10) and ((c-1)>=0) and (img[r+shift][c-k])==1:
                r+=shift
                c-=k
                break
            elif ((r-shift)>=0) and ((c-1)>=0) and (img[r-shift][c-k])==1:
                r-=shift
                c-=k
                break
            shift+=1
    if img[r][c]!=1:
        cnt+=1
    
    
    img[r][c]=0.79
    img=img*255
    img2=np.ones(shape=(w,w,3))
    scale=w/10
    for row in range(w):
        for col in range(w):
          for d in range(3):
            img2[row][col][d]=img[int(row/scale)][int(col/scale)]
    
    
    imglist.append((img2,Array[i][0],Array[i][36]))

count=0
for (img,id,i) in imglist[:]:
    plt.imshow(img)
    

    cv2.imwrite(str(id)+'_'+str(count)+'_'+str(w)+'_'+str(i)+'.jpg',img)

    count+=1

# %%
X=[]
y=[]
for i in imglist:
    X.append(i[0])
    y.append(i[2])
    
#print("YYY",y)
X=np.asarray(X)
#X=X.reshape(683,10,10,1)
y=np.asarray(y)
#print("YYY",y)

for i in range(y.shape[0]):
    if y[i]=='g':
        y[i]=1
    elif y[i]=='b':
        y[i]=0

# %%
import random
import gc 
import cv2
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')
del Array
del imglist
gc.collect()
#Convert list to numpy array
X = np.array(X)
y = np.array(y)
#print("YYYYYY",y)
#X_test=np.array(X_test)
#y_test=np.array(y_test)
#Lets plot the label to be sure we just have two class
sns.countplot(y)
#plt.title('Labels for g and b')
print("Shape of train images is:", X.shape)
print("Shape of labels is:", y.shape)

print("Length of X:", len(X))
# Out:
# Shape of train images is: (351, 100, 100, 3)
# Shape of labels is: (351,)
# Length of X: 351

# %%
from tensorflow.keras import layers
from tensorflow .keras import models
#from tensorflow.keras.applications import InceptionResNetV2
#conv_base = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(w,w,3))

model = models.Sequential()
model.add(layers.Conv2D(64, kernel_size=(2,2), input_shape=(w,w,3),strides=(2,2),activation='relu'))
model.add(layers.Conv2D(64, kernel_size=(2,2), strides=(2,2),activation='relu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.4))
model.add(layers.Conv2D(128, kernel_size=(2,2),strides=(2,2),activation='relu'))
model.add(layers.Conv2D(128, kernel_size=(2,2),strides=(2,2),activation='relu'))
#model.add(layers.MaxPooling2D(pool_size=(2, 2)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(256,activation='relu'))
model.add(layers.Dropout(0.4))
model.add(layers.Dense(1,activation='sigmoid'))
model.summary()

from tensorflow.keras import optimizers
model.compile(loss='binary_crossentropy', optimizer=optimizers.RMSprop(lr=2e-4), metrics=['acc'])
# Out:
# C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\kdc59\anaconda3\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 50, 50, 64)        832
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 25, 25, 64)        16448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 6, 6, 128)         32896
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         65664
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1152)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               295168
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 411,265
# Trainable params: 411,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img
train_datagen = ImageDataGenerator(rescale=1./1.)
val_datagen = ImageDataGenerator(rescale=1./1.)
batch_size = 32 
from sklearn.model_selection import StratifiedKFold

weights=[]

from sklearn.model_selection import KFold
kf = StratifiedKFold(n_splits=10,random_state=None)
Wsave = model.get_weights()
historylist=[]
val_accuracies=[]
test_accuracies=[]
for train_index, val_index in kf.split(X,y):
#     if i>1:
#       break
#     i+=1
    #print((test_index).shape)
    model.set_weights(Wsave)
    X_train,X_val=X[train_index],X[val_index]
    y_train,y_val=y[train_index],y[val_index]
    ntrain=len(X_train)
    nval=len(X_val)
    #print("Lengthhh:",nval)
    train_generator = train_datagen.flow(X_train, y_train,batch_size=batch_size)
    val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)
    #history=model.fit_generator(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
    historylist.append(model.fit_generator(train_generator,
                              steps_per_epoch=ntrain // batch_size,
                                       epochs=20,
                                      validation_data=val_generator,
                              validation_steps=nval // batch_size))
    val_score = model.evaluate(X_val,y_val,verbose=0)
    val_accuracies.append(val_score[1]*100)
    #test_score = model.evaluate(X_test,y_test,verbose=0)
    #test_accuracies.append(test_score[1]*100)
    weights.append(model.get_weights())
    
print("validation Accuracy:", val_accuracies)
print("Mean Validation Accuracy::",np.asarray(val_accuracies).mean())
# Out:
# Epoch 1/20
# 2/2 [==============================] - 0s 17ms/step - loss: 0.